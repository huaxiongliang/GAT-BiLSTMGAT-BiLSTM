# %%
import torch

path = "cora/"
cites = path + "cora_cites.txt"
content = path + "cora_content.txt"

# 索引字典，将原本的论文id转换到从0开始编码
index_dict = dict()
# 标签字典，将字符串标签转化为数值
label_to_index = dict()

features = []
labels = []
edge_index = []

with open(content,"r") as f:
    nodes = f.readlines()
    for node in nodes:
        node_info = node.split()
        index_dict[int(node_info[0])] = len(index_dict)
        features.append([int(i) for i in node_info[1:-1]])
        
        label_str = node_info[-1]
        if(label_str not in label_to_index.keys()):
            label_to_index[label_str] = len(label_to_index)
        labels.append(label_to_index[label_str])

with open(cites,"r") as f:
    edges = f.readlines()
    for edge in edges:
        start, end = edge.split()
        # 训练时将边视为无向的，但原本的边是有向的，因此需要正反添加两次
        edge_index.append([index_dict[int(start)],index_dict[int(end)]])
        edge_index.append([index_dict[int(end)],index_dict[int(start)]])

# 为每个节点增加自环，但后续GCN层默认会添加自环，跳过即可
# for i in range(2708):
#     edge_index.append([i,i])
  
# 转换为Tensor
labels = torch.LongTensor(labels)
features = torch.FloatTensor(features)
# 行归一化
# features = torch.nn.functional.normalize(features, p=1, dim=1)
edge_index =  torch.LongTensor(edge_index)

# %%
class GCNNet(torch.nn.Module):
    def __init__(self, num_feature, num_label):
        super(GCNNet,self).__init__()
        self.GCN1 = GCNConv(num_feature, 128)
        self.GCN2 = GCNConv(128, 64)
        self.GCN3 = GCNConv(64,32)
        self.GCN4 = GCNConv(32,num_label)  
        self.dropout = torch.nn.Dropout(p=0.3)
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        x = self.GCN1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.GCN2(x, edge_index)
        x = F.relu(x)
        x = self.GCN3(x,edge_index)
        x = F.relu(x)
        x = self.GCN4(x,edge_index)
        x = F.relu(x)
        
        return F.log_softmax(x, dim=1)

# %%
class GATNet(torch.nn.Module):
    def __init__(self, num_feature, num_label):
        super(GATNet,self).__init__()
        self.GAT1 = GATConv(num_feature, 8, heads = 8, concat = True, dropout = 0.6)
        self.GAT2 = GATConv(8*8, num_label, dropout = 0.6)  
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        x = self.GAT1(x, edge_index)
        x = F.relu(x)
        x = self.GAT2(x, edge_index)
        
        return F.log_softmax(x, dim=1)

# %%
import numpy as np
# seed = 1234
seed = 5678
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  
np.random.seed(seed)  # Numpy module.
# random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
from torch_geometric.data import Data

# %%
mask = torch.randperm(len(index_dict))
train_mask = mask[:140]
val_mask = mask[140:640]
test_mask = mask[1708:2708]

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

cora = Data(x = features, edge_index = edge_index.t().contiguous(), y = labels).to(device)

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,GATConv,SAGEConv
from torch_geometric.datasets import Planetoid

# %%
# model = GATNet(features.shape[1], len(label_to_index)).to(device)
model = GCNNet(features.shape[1], len(label_to_index)).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# epoch: 252 loss: 0.9647
# epoch: 253 loss: 1.1850
# epoch: 254 loss: 1.0417
# epoch: 255 loss: 0.8324
# epoch: 256 loss: 0.7871
# epoch: 257 loss: 0.7627
# epoch: 258 loss: 0.6210
# epoch: 259 loss: 0.5014
# Accuracy: 0.7380
# epoch: 260 loss: 0.3979
# epoch: 261 loss: 0.3107
# epoch: 262 loss: 0.3097
# epoch: 263 loss: 0.2956
# epoch: 264 loss: 0.2626
# epoch: 265 loss: 0.2745
# epoch: 266 loss: 0.2397
# epoch: 267 loss: 0.2122
# epoch: 268 loss: 0.1990
# epoch: 269 loss: 0.1898
# Accuracy: 0.7620
# epoch: 270 loss: 0.1895
# epoch: 271 loss: 0.1803
# epoch: 272 loss: 0.1809
# epoch: 273 loss: 0.1792
# epoch: 274 loss: 0.1721
# epoch: 275 loss: 0.1702
# epoch: 276 loss: 0.1619
# epoch: 277 loss: 0.1615
# epoch: 278 loss: 0.1592
# epoch: 279 loss: 0.1660
# Accuracy: 0.7740
# epoch: 280 loss: 0.1610
# epoch: 281 loss: 0.1553
# epoch: 282 loss: 0.1349
# epoch: 283 loss: 0.0971
# epoch: 284 loss: 0.0661
# epoch: 285 loss: 0.0435
# epoch: 286 loss: 0.0405
# epoch: 287 loss: 0.0351
# epoch: 288 loss: 0.0317
# epoch: 289 loss: 0.0235
# Accuracy: 0.7960
# epoch: 290 loss: 0.0309
# epoch: 291 loss: 0.0186
# epoch: 292 loss: 0.0156
# epoch: 293 loss: 0.0176
# epoch: 294 loss: 0.0130
# epoch: 295 loss: 0.0137
# epoch: 296 loss: 0.0167
# epoch: 297 loss: 0.0220
# epoch: 298 loss: 0.0144
# epoch: 299 loss: 0.0180
# Accuracy: 0.8060

# %%
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

import matplotlib


ts = TSNE(n_components=2)
ts.fit_transform(out[test_mask].to('cpu').detach().numpy())

x = ts.embedding_
y = cora.y[test_mask].to('cpu').detach().numpy()

xi = []
for i in range(7):
    xi.append(x[np.where(y==i)])

colors = ['mediumblue','green','red','yellow','cyan','mediumvioletred','mediumspringgreen']
plt.figure(figsize=(8, 6))
# plt.title('GCN_4_layer') 
for i in range(7):
    plt.scatter(xi[i][:,0],xi[i][:,1],s=30,color=colors[i],marker='o',alpha=1)

plt.savefig('GCN_4_layer_5678.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# mpl.rcParams['font.sans-serif'] = u'SimHei'
# 准备数据
x_data = ['Xgboost','Xgboost+LR','MLP','GBDT','GCC','GAT']
y_data = [76.37,76.75,68.19,77.31,82.60,83.50]

# 正确显示中文和负号
plt.rcParams["font.sans-serif"] = u'SimHei'
plt.rcParams["axes.unicode_minus"] = False
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

for a,b in zip(x_data,y_data):   #柱子上的数字显示
 plt.text(a,b,'%.2f'%b,ha='center',va='bottom',fontsize=7);


# 画图，plt.bar()可以画柱状图
for i in range(len(x_data)):
	plt.bar(x_data[i], y_data[i])
# 设置图片名称
# plt.title("模型准确率比较")
# 设置x轴标签名
# plt.xlabel("模型")
# 设置y轴标签名
plt.ylabel("准确率")
# 显示
# plt.show()


plt.savefig('model_5678.jpg', dpi=800,bbox_inches='tight')
