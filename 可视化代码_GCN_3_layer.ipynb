# %%
import torch

path = "cora/"
cites = path + "cora_cites.txt"
content = path + "cora_content.txt"

# 索引字典，将原本的论文id转换到从0开始编码
index_dict = dict()
# 标签字典，将字符串标签转化为数值
label_to_index = dict()

features = []
labels = []
edge_index = []

with open(content,"r") as f:
    nodes = f.readlines()
    for node in nodes:
        node_info = node.split()
        index_dict[int(node_info[0])] = len(index_dict)
        features.append([int(i) for i in node_info[1:-1]])
        
        label_str = node_info[-1]
        if(label_str not in label_to_index.keys()):
            label_to_index[label_str] = len(label_to_index)
        labels.append(label_to_index[label_str])

with open(cites,"r") as f:
    edges = f.readlines()
    for edge in edges:
        start, end = edge.split()
        # 训练时将边视为无向的，但原本的边是有向的，因此需要正反添加两次
        edge_index.append([index_dict[int(start)],index_dict[int(end)]])
        edge_index.append([index_dict[int(end)],index_dict[int(start)]])

# 为每个节点增加自环，但后续GCN层默认会添加自环，跳过即可
# for i in range(2708):
#     edge_index.append([i,i])
  
# 转换为Tensor
labels = torch.LongTensor(labels)
features = torch.FloatTensor(features)
# 行归一化
# features = torch.nn.functional.normalize(features, p=1, dim=1)
edge_index =  torch.LongTensor(edge_index)

# %%
class GCNNet(torch.nn.Module):
    def __init__(self, num_feature, num_label):
        super(GCNNet,self).__init__()
        self.GCN1 = GCNConv(num_feature, 64)
        self.GCN2 = GCNConv(64,16)
        self.GCN3 = GCNConv(16, num_label)  
        self.dropout = torch.nn.Dropout(p=0.3)
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        x = self.GCN1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.GCN2(x,edge_index)
        x = F.relu(x)

        x = self.GCN3(x, edge_index)
        
        x = F.relu(x)

        return F.log_softmax(x, dim=1)

# %%
class GATNet(torch.nn.Module):
    def __init__(self, num_feature, num_label):
        super(GATNet,self).__init__()
        self.GAT1 = GATConv(num_feature, 8, heads = 8, concat = True, dropout = 0.6)
        self.GAT2 = GATConv(8*8, num_label, dropout = 0.6)  
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        x = self.GAT1(x, edge_index)
        x = F.relu(x)
        x = self.GAT2(x, edge_index)
        
        return F.log_softmax(x, dim=1)

# %%
import numpy as np
# seed = 1234
seed = 5678
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  
np.random.seed(seed)  # Numpy module.
# random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
from torch_geometric.data import Data

# %%
mask = torch.randperm(len(index_dict))
train_mask = mask[:140]
val_mask = mask[140:640]
test_mask = mask[1708:2708]

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

cora = Data(x = features, edge_index = edge_index.t().contiguous(), y = labels).to(device)

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,GATConv,SAGEConv
from torch_geometric.datasets import Planetoid

# %%
# model = GATNet(features.shape[1], len(label_to_index)).to(device)
model = GCNNet(features.shape[1], len(label_to_index)).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

for epoch in range(300):
    optimizer.zero_grad()
    out = model(cora)
    loss = F.nll_loss(out[train_mask], cora.y[train_mask])
    print('epoch: %d loss: %.4f' %(epoch, loss))
    loss.backward()
    optimizer.step()
    
    if((epoch + 1)% 10 == 0):
        model.eval()
        _, pred = model(cora).max(dim=1)
        correct = int(pred[test_mask].eq(cora.y[test_mask]).sum().item())
        acc = correct / len(test_mask)
        print('Accuracy: {:.4f}'.format(acc))
        model.train()
# Out:
# epoch: 0 loss: 1.9376
# epoch: 1 loss: 1.8286
# epoch: 2 loss: 1.6897
# epoch: 3 loss: 1.5549
# epoch: 4 loss: 1.4137
# epoch: 5 loss: 1.2632
# epoch: 6 loss: 1.1312
# epoch: 7 loss: 1.0182
# epoch: 8 loss: 0.9071
# epoch: 9 loss: 0.8276
# Accuracy: 0.5480
# epoch: 10 loss: 0.7652
# epoch: 11 loss: 0.7061
# epoch: 12 loss: 0.6718
# epoch: 13 loss: 0.6454
# epoch: 14 loss: 0.6280
# epoch: 15 loss: 0.6102
# epoch: 16 loss: 0.5991
# epoch: 17 loss: 0.5837
# epoch: 18 loss: 0.5328
# epoch: 19 loss: 0.4877
# Accuracy: 0.5820
# epoch: 20 loss: 0.4807
# epoch: 21 loss: 0.4421
# epoch: 22 loss: 0.4062
# epoch: 23 loss: 0.3976
# epoch: 24 loss: 0.3737
# epoch: 25 loss: 0.3743
# epoch: 26 loss: 0.3649
# epoch: 27 loss: 0.3607
# epoch: 28 loss: 0.3657
# epoch: 29 loss: 0.3607
# Accuracy: 0.6110
# epoch: 30 loss: 0.3501
# epoch: 31 loss: 0.3474
# epoch: 32 loss: 0.3432
# epoch: 33 loss: 0.3328
# epoch: 34 loss: 0.3177
# epoch: 35 loss: 0.2969
# epoch: 36 loss: 0.2784
# epoch: 37 loss: 0.2649
# epoch: 38 loss: 0.2526
# epoch: 39 loss: 0.2447
# Accuracy: 0.7420
# epoch: 40 loss: 0.2337
# epoch: 41 loss: 0.2216
# epoch: 42 loss: 0.2121
# epoch: 43 loss: 0.2069
# epoch: 44 loss: 0.1925
# epoch: 45 loss: 0.1833
# epoch: 46 loss: 0.1769
# epoch: 47 loss: 0.1728
# epoch: 48 loss: 0.1704
# epoch: 49 loss: 0.1663
# Accuracy: 0.7510
# epoch: 50 loss: 0.1597
# epoch: 51 loss: 0.1567
# epoch: 52 loss: 0.1540
# epoch: 53 loss: 0.1537
# epoch: 54 loss: 0.1532
# epoch: 55 loss: 0.1509
# epoch: 56 loss: 0.1567
# epoch: 57 loss: 0.1513
# epoch: 58 loss: 0.1495
# epoch: 59 loss: 0.1471
# Accuracy: 0.7810
# epoch: 60 loss: 0.1485
# epoch: 61 loss: 0.1493
# epoch: 62 loss: 0.1502
# epoch: 63 loss: 0.1476
# epoch: 64 loss: 0.1472
# epoch: 65 loss: 0.1493
# epoch: 66 loss: 0.1500
# epoch: 67 loss: 0.1453
# epoch: 68 loss: 0.1455
# epoch: 69 loss: 0.1461
# Accuracy: 0.7710
# epoch: 70 loss: 0.1473
# epoch: 71 loss: 0.1439
# epoch: 72 loss: 0.1450
# epoch: 73 loss: 0.1444
# epoch: 74 loss: 0.1483
# epoch: 75 loss: 0.1441
# epoch: 76 loss: 0.1477
# epoch: 77 loss: 0.1423
# epoch: 78 loss: 0.1410
# epoch: 79 loss: 0.1426
# Accuracy: 0.7660
# epoch: 80 loss: 0.1423
# epoch: 81 loss: 0.1420
# epoch: 82 loss: 0.1460
# epoch: 83 loss: 0.1421
# epoch: 84 loss: 0.1415
# epoch: 85 loss: 0.1434
# epoch: 86 loss: 0.1473
# epoch: 87 loss: 0.1401
# epoch: 88 loss: 0.1415
# epoch: 89 loss: 0.1454
# Accuracy: 0.7770
# epoch: 90 loss: 0.1426
# epoch: 91 loss: 0.1511
# epoch: 92 loss: 0.1413
# epoch: 93 loss: 0.1412
# epoch: 94 loss: 0.1440
# epoch: 95 loss: 0.1436
# epoch: 96 loss: 0.1408
# epoch: 97 loss: 0.1410
# epoch: 98 loss: 0.1413
# epoch: 99 loss: 0.1432
# Accuracy: 0.7740
# epoch: 100 loss: 0.1404
# epoch: 101 loss: 0.1413
# epoch: 102 loss: 0.1408
# epoch: 103 loss: 0.1394
# epoch: 104 loss: 0.1397
# epoch: 105 loss: 0.1378
# epoch: 106 loss: 0.1386
# epoch: 107 loss: 0.1427
# epoch: 108 loss: 0.1395
# epoch: 109 loss: 0.1419
# Accuracy: 0.7600
# epoch: 110 loss: 0.1401
# epoch: 111 loss: 0.1412
# epoch: 112 loss: 0.1397
# epoch: 113 loss: 0.1376
# epoch: 114 loss: 0.1397
# epoch: 115 loss: 0.1414
# epoch: 116 loss: 0.1415
# epoch: 117 loss: 0.1585
# epoch: 118 loss: 0.1386
# epoch: 119 loss: 0.1410
# Accuracy: 0.7550
# epoch: 120 loss: 0.1417
# epoch: 121 loss: 0.1505
# epoch: 122 loss: 0.1413
# epoch: 123 loss: 0.1368
# epoch: 124 loss: 0.1446
# epoch: 125 loss: 0.1480
# epoch: 126 loss: 0.1426
# epoch: 127 loss: 0.1376
# epoch: 128 loss: 0.1441
# epoch: 129 loss: 0.1442
# Accuracy: 0.7590
# epoch: 130 loss: 0.1380
# epoch: 131 loss: 0.1377
# epoch: 132 loss: 0.1388
# epoch: 133 loss: 0.1365
# epoch: 134 loss: 0.1388
# epoch: 135 loss: 0.1414
# epoch: 136 loss: 0.1386
# epoch: 137 loss: 0.1355
# epoch: 138 loss: 0.1387
# epoch: 139 loss: 0.1395
# Accuracy: 0.7640
# epoch: 140 loss: 0.1361
# epoch: 141 loss: 0.1396
# epoch: 142 loss: 0.1346
# epoch: 143 loss: 0.1463
# epoch: 144 loss: 0.1396
# epoch: 145 loss: 0.1402
# epoch: 146 loss: 0.1358
# epoch: 147 loss: 0.1350
# epoch: 148 loss: 0.1352
# epoch: 149 loss: 0.1358
# Accuracy: 0.7530
# epoch: 150 loss: 0.1362
# epoch: 151 loss: 0.1354
# epoch: 152 loss: 0.1363
# epoch: 153 loss: 0.1338
# epoch: 154 loss: 0.1368
# epoch: 155 loss: 0.1358
# epoch: 156 loss: 0.1358
# epoch: 157 loss: 0.1381
# epoch: 158 loss: 0.1353
# epoch: 159 loss: 0.1345
# Accuracy: 0.7640
# epoch: 160 loss: 0.1401
# epoch: 161 loss: 0.1350
# epoch: 162 loss: 0.1361
# epoch: 163 loss: 0.1355
# epoch: 164 loss: 0.1360
# epoch: 165 loss: 0.1348
# epoch: 166 loss: 0.1377
# epoch: 167 loss: 0.1347
# epoch: 168 loss: 0.1335
# epoch: 169 loss: 0.1350
# Accuracy: 0.7740
# epoch: 170 loss: 0.1371
# epoch: 171 loss: 0.1376
# epoch: 172 loss: 0.1345
# epoch: 173 loss: 0.1357
# epoch: 174 loss: 0.1372
# epoch: 175 loss: 0.1375
# epoch: 176 loss: 0.1335
# epoch: 177 loss: 0.1411
# epoch: 178 loss: 0.1403
# epoch: 179 loss: 0.1350
# Accuracy: 0.7610
# epoch: 180 loss: 0.1376
# epoch: 181 loss: 0.1521
# epoch: 182 loss: 0.1373
# epoch: 183 loss: 0.1435
# epoch: 184 loss: 0.1391
# epoch: 185 loss: 0.1432
# epoch: 186 loss: 0.1330
# epoch: 187 loss: 0.1369
# epoch: 188 loss: 0.1423
# epoch: 189 loss: 0.1353
# Accuracy: 0.7620
# epoch: 190 loss: 0.1336
# epoch: 191 loss: 0.1395
# epoch: 192 loss: 0.1387
# epoch: 193 loss: 0.1355
# epoch: 194 loss: 0.1329
# epoch: 195 loss: 0.1347
# epoch: 196 loss: 0.1374
# epoch: 197 loss: 0.1352
# epoch: 198 loss: 0.1338
# epoch: 199 loss: 0.1357
# Accuracy: 0.7650
# epoch: 200 loss: 0.1349
# epoch: 201 loss: 0.1342
# epoch: 202 loss: 0.1346
# epoch: 203 loss: 0.1333
# epoch: 204 loss: 0.1336
# epoch: 205 loss: 0.1403
# epoch: 206 loss: 0.1336
# epoch: 207 loss: 0.1333
# epoch: 208 loss: 0.1340
# epoch: 209 loss: 0.1348
# Accuracy: 0.7650
# epoch: 210 loss: 0.1328
# epoch: 211 loss: 0.1351
# epoch: 212 loss: 0.1362
# epoch: 213 loss: 0.1374
# epoch: 214 loss: 0.1341
# epoch: 215 loss: 0.1462
# epoch: 216 loss: 0.1374
# epoch: 217 loss: 0.1362
# epoch: 218 loss: 0.1346
# epoch: 219 loss: 0.1368
# Accuracy: 0.7720
# epoch: 220 loss: 0.1396
# epoch: 221 loss: 0.1341
# epoch: 222 loss: 0.1342
# epoch: 223 loss: 0.1353
# epoch: 224 loss: 0.1352
# epoch: 225 loss: 0.1323
# epoch: 226 loss: 0.1349
# epoch: 227 loss: 0.1328
# epoch: 228 loss: 0.1350
# epoch: 229 loss: 0.1364
# Accuracy: 0.7730
# epoch: 230 loss: 0.1319
# epoch: 231 loss: 0.1330
# epoch: 232 loss: 0.1352
# epoch: 233 loss: 0.1344
# epoch: 234 loss: 0.1359
# epoch: 235 loss: 0.1320
# epoch: 236 loss: 0.1335
# epoch: 237 loss: 0.1332
# epoch: 238 loss: 0.1330
# epoch: 239 loss: 0.1340
# Accuracy: 0.7640
# epoch: 240 loss: 0.1338
# epoch: 241 loss: 0.1330
# epoch: 242 loss: 0.1328
# epoch: 243 loss: 0.1333
# epoch: 244 loss: 0.1359
# epoch: 245 loss: 0.1323
# epoch: 246 loss: 0.1366
# epoch: 247 loss: 0.1337
# epoch: 248 loss: 0.1334
# epoch: 249 loss: 0.1334
# Accuracy: 0.7490
# epoch: 250 loss: 0.1344
# epoch: 251 loss: 0.1321
# epoch: 252 loss: 0.1362
# epoch: 253 loss: 0.1351
# epoch: 254 loss: 0.1355
# epoch: 255 loss: 0.1350
# epoch: 256 loss: 0.1349
# epoch: 257 loss: 0.1330
# epoch: 258 loss: 0.1366
# epoch: 259 loss: 0.1327
# Accuracy: 0.7620
# epoch: 260 loss: 0.1320
# epoch: 261 loss: 0.1320
# epoch: 262 loss: 0.1336
# epoch: 263 loss: 0.1332
# epoch: 264 loss: 0.1337
# epoch: 265 loss: 0.1328
# epoch: 266 loss: 0.1323
# epoch: 267 loss: 0.1320
# epoch: 268 loss: 0.1313
# epoch: 269 loss: 0.1330
# Accuracy: 0.7670
# epoch: 270 loss: 0.1322
# epoch: 271 loss: 0.1335
# epoch: 272 loss: 0.1317
# epoch: 273 loss: 0.1335
# epoch: 274 loss: 0.1347
# epoch: 275 loss: 0.1345
# epoch: 276 loss: 0.1336
# epoch: 277 loss: 0.1343
# epoch: 278 loss: 0.1316
# epoch: 279 loss: 0.1357
# Accuracy: 0.7690
# epoch: 280 loss: 0.1342
# epoch: 281 loss: 0.1349
# epoch: 282 loss: 0.1352
# epoch: 283 loss: 0.1341
# epoch: 284 loss: 0.1337
# epoch: 285 loss: 0.1329
# epoch: 286 loss: 0.1408
# epoch: 287 loss: 0.1322
# epoch: 288 loss: 0.1358
# epoch: 289 loss: 0.1346
# Accuracy: 0.7550
# epoch: 290 loss: 0.1328
# epoch: 291 loss: 0.1319
# epoch: 292 loss: 0.1321
# epoch: 293 loss: 0.1336
# epoch: 294 loss: 0.1313
# epoch: 295 loss: 0.1311
# epoch: 296 loss: 0.1319
# epoch: 297 loss: 0.1329
# epoch: 298 loss: 0.1332
# epoch: 299 loss: 0.1334
# Accuracy: 0.7640

# %%
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

import matplotlib


ts = TSNE(n_components=2)
ts.fit_transform(out[test_mask].to('cpu').detach().numpy())

x = ts.embedding_
y = cora.y[test_mask].to('cpu').detach().numpy()

xi = []
for i in range(7):
    xi.append(x[np.where(y==i)])

colors = ['mediumblue','green','red','yellow','cyan','mediumvioletred','mediumspringgreen']
plt.figure(figsize=(8, 6))
# plt.title('GCN_3_layer') 
for i in range(7):
    plt.scatter(xi[i][:,0],xi[i][:,1],s=30,color=colors[i],marker='o',alpha=1)
plt.savefig('GCN_3_layer_5678.png')
